# %% [markdown]
# We need to evaluate existing models performance on code-switching (EN-ES) scenarios. To do this, I will use an online datasets and compare the performance of base models with the performance of the model that I think will do better.

# %% [markdown]
# Because model performance on a dataset does not necessarily correlate to model performance on the DINA data, here is a ranking of the models performance on the DINA data so that we can know what to expect when we run these models on the online dataset.

# %% [markdown]
# How well a model has worked on DINA
# 1) AWS 8/10
# 2) Sonix 7.8/10
# 3) WhisperX (Large) 6.5/10
# 4) Whisper (Medium) 6/10
# 5) Whisper (Large) 5.5/10
# 6) Whisper (Small) 3/10
# 7) Whisper (Turbo) 3/10
#
# Note: This is largely just perceptual and only based off of what I notice from seeing these models ran on 1 participant: DINA1_freeplay

# %% [markdown]
# It was hard finding a EN-ES code switching dataset that had both transcripts, audio, and word timestamps. Thus, I'll evaluate ASR separately from Forced Alignment.

# %% [markdown]
# # Setup

# %% [markdown]
# The dataset can be downloaded here: https://bangortalk.org.uk/speakers.php?c=miami
