# %% [markdown]
# # Setup

# %% [markdown]
# (setup)

# %% [markdown]
# # Transcription

# %% [markdown]
# We have a good way to get onsets and offsets of words (both in English and Spanish) through forced alignment.
# - Specifically, we saw that MFA works the best in this task.
#
# However, forced alignment requires you to have the text transcripts already. Currently, AWS is good at producing the English-Spanish codeswitching transcripts when the switching is happening between sentences, but it's failing at doing it when the switching is happening within the sentence.
#
# My idea:
# 1) Finetune Whisper Large on Ruby & Adalai's URC corrected transcripts
#     - This allows us to leverage a number of things:
#       - Whisper's multilingual ability as an "initial skill"
#       - AWS transcription accuracy as an "additional finetuned skill"
#       - Ruby & Adalai's transcriptions as "reinforcement from human feedback"
# 2) Plug in this finetuned Whisper Large model into WhisperX
#     - This gives us additional features that WhisperX offers such as VAD, Speaker diarization, and alignment (though we probably won't use it)
# 3) Finally, plug this into the English-Spanish MFA setup for word-level timestamps
#     - We can then reverse engineer utterance separations from our own definitions.

# %% [markdown]
# # Outline

# %% [markdown]
# 1. Data collection
#     - Grab the coder annotated TextGrids and the corresponding audio files of code-switched data
# 2. Data preparation
#     - Cut out sections of the audio files where the utterances happen
#     - Standardize the transcript text
# 3. Finetune Whisper (I have code that does this already)
# 4. Visualize
#
# Noisy data:
# - Child vocalizations, background noise, multiple speakers, intersentential code-switching
#   - The idea is that by finetuning, we're teaching the model:
#       - to "filter out" this noise and only produce the transcriptions of the parent.
#       - to handle English-Spanish codeswitching
#       - while still being an multilingual ASR model

# %% [markdown]
# # 1) Data collection

# %% [markdown]
# TextGrids: Downloaded from Server/general/Studies/DINA/Coding/Transcripts/Textgrids/Play_V1_txt
#
# Audio: Downloaded from Server/general/Studies/DINA/6_Audio_Recordings/Playsession_Audio/Playsession_Audio_WAV/V1playWAV

# %% [markdown]
# # 2) Data preparation

# %%
# The tier that was annotated to have AWS + coder editted transcripts was inconsistent across participants, so I manually checked for them here.

participantID2transcriptTier = { # NOTE: This is 1-indexed
  1: 6,
  2: 6,
  3: 2,
  4: 6,
  5: 4,
  6: 6,
  7: 4,
  8: 6,
  9: 4,
  10: 6,
  11: 4,
  12: 6,
  13: 4,
  14: 4,
  15: 6,
  16: 4,
  17: 6,
  18: 2,
  19: 4,
  20: 4,
  21: 4,
  22: 4,
  23: 4,
  24: 4,
  25: 3,
  26: 4,
  27: 4,
  28: 4,
  30: 3,
  31: 4,
  32: 4,
  33: 3,
  34: 2,
  35: 3,
  36: 3,
  37: 3,
  38: 3,
  39: 3,
  40: 3,
  41: 2,
  42: 3,
  43: 2,
  45: 3,
  46: 3,
  47: 3,
  48: 3,
  49: 3,
  51: 3,
  58: 3,
  64: 2,
}

"""
6: I think these ones are the most reliable. They include multiple utterance tiers
4: These ones should be good too.
3: These ones I think were only coded by 1 coder? Or maybe they're just combined
2: These ones aren't coded / didn't need coding / are already editted? Not sure
"""
# Out:
# "\n6: I think these ones are the most reliable. They include multiple utterance tiers\n4: These ones should be good too.\n3: These ones I think were only coded by 1 coder? Or maybe they're just combined\n2: These ones aren't coded / didn't need coding / are already editted? Not sure\n"

# %%
# # This was a Claude generated file. I use it as a reference to code the next snippet
# """
# cut_intervals.py

# For each TextGrid in a folder, reads a specified interval tier and cuts the
# corresponding segments from the matching audio file. Outputs one audio file
# per interval, named: {base}_{tier}_{index}_{label}.wav

# Dependencies:
#     pip install tgt pydub
#     # pydub also needs ffmpeg installed:
#     # macOS:   brew install ffmpeg
#     # Ubuntu:  sudo apt install ffmpeg
#     # Windows: https://ffmpeg.org/download.html

# Usage:
#     python cut_intervals.py \
#         --textgrid-dir /path/to/textgrids \
#         --audio-dir    /path/to/audio \
#         --tier-name    "phones" \
#         --output-dir   /path/to/output \
#         [--skip-empty]           # skip intervals with empty labels
#         [--audio-ext .wav]       # audio extension (default: .wav)
# """

# import argparse
# import os
# import sys
# import tgt
# from pydub import AudioSegment


# def cut_intervals(
#     textgrid_dir: str,
#     audio_dir: str,
#     tier_name: str,
#     output_dir: str,
#     skip_empty: bool = True,
#     audio_ext: str = ".wav",
# ):
#     os.makedirs(output_dir, exist_ok=True)

#     tg_files = [f for f in os.listdir(textgrid_dir) if f.endswith(".TextGrid")]

#     if not tg_files:
#         print("No .TextGrid files found in", textgrid_dir)
#         sys.exit(1)

#     for tg_filename in sorted(tg_files):
#         base = os.path.splitext(tg_filename)[0]
#         tg_path = os.path.join(textgrid_dir, tg_filename)
#         audio_path = os.path.join(audio_dir, base + audio_ext)

#         # --- load TextGrid ---
#         try:
#             tg = tgt.io.read_textgrid(tg_path)
#         except Exception as e:
#             print(f"[WARN] Could not read TextGrid '{tg_filename}': {e}")
#             continue

#         # --- find tier ---
#         if tier_name not in tg.get_tier_names():
#             print(
#                 f"[WARN] Tier '{tier_name}' not found in '{tg_filename}'. "
#                 f"Available tiers: {tg.get_tier_names()}"
#             )
#             continue

#         tier = tg.get_tier_by_name(tier_name)
#         if not isinstance(tier, tgt.core.IntervalTier):
#             print(f"[WARN] Tier '{tier_name}' in '{tg_filename}' is not an IntervalTier.")
#             continue

#         # --- load audio ---
#         if not os.path.isfile(audio_path):
#             print(f"[WARN] Audio file not found: '{audio_path}'")
#             continue

#         try:
#             audio = AudioSegment.from_file(audio_path)
#         except Exception as e:
#             print(f"[WARN] Could not load audio '{audio_path}': {e}")
#             continue

#         print(f"Processing '{tg_filename}' ({len(tier)} intervals)...")

#         # --- cut each interval ---
#         for i, interval in enumerate(tier):
#             label = interval.text.strip()

#             if skip_empty and label == "":
#                 continue

#             # tgt times are in seconds; pydub uses milliseconds
#             start_ms = interval.start_time * 1000
#             end_ms = interval.end_time * 1000

#             segment = audio[start_ms:end_ms]

#             # sanitise label for use in filename
#             safe_label = "".join(c if c.isalnum() or c in "-_" else "_" for c in label)
#             out_filename = f"{base}_{tier_name}_{i:04d}_{safe_label}{audio_ext}"
#             out_path = os.path.join(output_dir, out_filename)

#             fmt = audio_ext.lstrip(".")
#             segment.export(out_path, format=fmt)

#     print("\nDone! Output written to:", output_dir)


# def main():
#     parser = argparse.ArgumentParser(
#         description="Cut audio intervals defined in Praat TextGrids."
#     )
#     parser.add_argument(
#         "--textgrid-dir", required=True,
#         help="Folder containing .TextGrid files."
#     )
#     parser.add_argument(
#         "--audio-dir", required=True,
#         help="Folder containing audio files (must share basenames with TextGrids)."
#     )
#     parser.add_argument(
#         "--tier-name", required=True,
#         help="Name of the IntervalTier to use."
#     )
#     parser.add_argument(
#         "--output-dir", required=True,
#         help="Folder where cut audio segments will be saved."
#     )
#     parser.add_argument(
#         "--skip-empty", action="store_true", default=True,
#         help="Skip intervals with empty labels (default: True)."
#     )
#     parser.add_argument(
#         "--no-skip-empty", dest="skip_empty", action="store_false",
#         help="Include intervals with empty labels."
#     )
#     parser.add_argument(
#         "--audio-ext", default=".wav",
#         help="Audio file extension, e.g. .wav or .mp3 (default: .wav)."
#     )

#     args = parser.parse_args()

#     cut_intervals(
#         textgrid_dir=args.textgrid_dir,
#         audio_dir=args.audio_dir,
#         tier_name=args.tier_name,
#         output_dir=args.output_dir,
#         skip_empty=args.skip_empty,
#         audio_ext=args.audio_ext,
#     )


# if __name__ == "__main__":
#     main()

# %%
pip install pydub TextGrid
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from textgrid import TextGrid
from pydub import AudioSegment

# Initialize paths
textgrid_dir = "../input/finetuning_data/textgrids"
audio_dir = "../input/finetuning_data/audio"
output_dir = "../input/finetuning_data/snippets"
audio_ext = ".wav"
total_intervals = 0

# What an empty interval looks like
EMPTY = ["sil", " sil", "sil ", " sil ",
         "SIL", " SIL", "SIL ", " SIL ",
         "", " "]

# Make an output directory if it doesn't exist already
os.makedirs(output_dir, exist_ok=True)

# Iterat ethrough each participant
for participant_id in participantID2transcriptTier.keys():

    # --- initialize variables ---
    transcript_tier = participantID2transcriptTier[participant_id]
    tg_filename = f"DINA{participant_id}_v1.TextGrid"
    base = os.path.splitext(tg_filename)[0]
    tg_path = os.path.join(textgrid_dir, tg_filename)
    audio_path = os.path.join(audio_dir, base + audio_ext)

    if transcript_tier not in [6, 4, 3]:
        continue

    # --- load TextGrid ---
    if not os.path.exists(tg_path):
        print(f"[WARN] {tg_path} doesn't exist")
        continue
    try:
        curr_textgrid = TextGrid()
        curr_textgrid.read(tg_path)
    except Exception as e:
        print(f"[WARN] Could not read TextGrid '{tg_filename}': {e}")
        continue

    # --- load audio ---
    if not os.path.exists(audio_path):
        print(f"[WARN] {audio_path} doesn't exist")
        continue
    if not os.path.isfile(audio_path):
        print(f"[WARN] Audio file not found: '{audio_path}'")
        continue

    try:
        audio = AudioSegment.from_file(audio_path)
    except Exception as e:
        print(f"[WARN] Could not load audio '{audio_path}': {e}")
        continue

    # --- grab intervals from specified tier ---
    intervals = [interval for interval in curr_textgrid[transcript_tier-1]]

    # --- cut each interval ---
    print(f"Processing '{tg_filename}' ({len(intervals)} intervals)...")
    for i, interval in enumerate(intervals):

        # Initialize variables
        start = interval.minTime
        end = interval.maxTime
        text = interval.mark

        # If text is empty we can skip it
        if not text or text in EMPTY:
            continue

        # TextGrid times are in seconds; pydub uses milliseconds
        start_ms = start * 1000
        end_ms = end * 1000

        # Grab segment from audio file
        segment = audio[start_ms:end_ms]

        # sanitise label for use in filename
        sanitized_text = "".join(c if c.isalnum() or c in "-_'" else "-" for c in text.strip().replace("  ", " ").replace("   ", " "))
        out_filename = f"{base}_{i:04d}_{sanitized_text}{audio_ext}"
        out_path = os.path.join(output_dir, out_filename)

        # export
        try:
            fmt = audio_ext.lstrip(".")
            segment.export(out_path, format=fmt)
            total_intervals += 1
        except Exception as e:
            print(f"{e}, Could not export: {out_filename}")
print(f"\nDone! Exported {total_intervals} total intervals")
# Out:
# Processing 'DINA1_v1.TextGrid' (471 intervals)...
# Processing 'DINA2_v1.TextGrid' (189 intervals)...
# Processing 'DINA4_v1.TextGrid' (237 intervals)...
# [Errno 36] File name too long: "../input/finetuning_data/snippets/DINA4_v1_0232_shakers--we-shake-our-shakers-together--we-shake-our-shakers-together--we-shake-our-shakers-together-because-it's-fun-to-do--Shake-them-up-high--shake-them-down-low--We-shake-them-in-the-middle-because-it's-fun-to-do--We-shake-our-shakers-together--we-shake-our-shakers-together-.wav", Could not export: DINA4_v1_0232_shakers--we-shake-our-shakers-together--we-shake-our-shakers-together--we-shake-our-shakers-together-because-it's-fun-to-do--Shake-them-up-high--shake-them-down-low--We-shake-them-in-the-middle-because-it's-fun-to-do--We-shake-our-shakers-together--we-shake-our-shakers-together-.wav
# Processing 'DINA5_v1.TextGrid' (209 intervals)...
# Processing 'DINA6_v1.TextGrid' (217 intervals)...
# Processing 'DINA7_v1.TextGrid' (156 intervals)...
# ...

# %% [markdown]
# Then, briefly go through these files and check for any bad participants.
#
# This might be a result of incorrect file paths, script errors, etc...
#
# For me:
# - 8, 35, 36 the mic sounds far away
# - 13 the mic is far away & not synced with Praat
# - The audio is only in the left channel for many participants (I think Whisper preprocessing handles this by converting all stereo into mono)
# - Also for some participants, the audio isn't far away but it's quiet.

# %%
# Some EDA to know exactly what we're feeding into the model
import pandas as pd

"""
Things to look at:
- Audio length
- Utterance length
- Special characters / coder notes
- Total audio length
- Language percentage
"""

# From another script I made: praat/detect_language.py
import os
from lingua import Language, LanguageDetectorBuilder
def detect_language(detector, text):
    # Detect the language of the given text through punctuation or through a model
    if any(char in text for char in "¡¿áéíóúñüÁÉÍÓÚÑÜ"):
        return "Spanish"
    result = detector.detect_language_of(text)
    if result == Language.ENGLISH:
        return "English"
    elif result == Language.SPANISH:
        return "Spanish"
    return "Unknown"

# Initialize the language detector for English and Spanish
languages = [Language.ENGLISH, Language.SPANISH]
detector = LanguageDetectorBuilder.from_languages(*languages).build()

# Grab all snippets and put them into a dataframe
snippets_path = '../input/finetuning_data/snippets'
snippet_files = [f for f in os.listdir(snippets_path) if f.endswith(".wav")]

snippet_df = []
for snippet_file in snippet_files:
  snippet_df.append({
    'full_path': f'../input/finetuning_data/snippets/{snippet_file}',
    'participant_id': snippet_file.split('_')[0].replace("DINA", ""),
    'interval_id': snippet_file.split('_')[2],
    'text': snippet_file.split('_')[3].replace(".wav", "").replace("-", " ")
  })

snippet_df = pd.DataFrame(snippet_df)

# Grab things to visualize
visualize_data = {'utterance_length':[],
                  'language':[],
                  'audio_length':[],}
for index, snippet in snippet_df.iterrows():
    visualize_data['utterance_length'].append(len(snippet['text'].split()))
    visualize_data['language'].append(detect_language(detector, snippet['text'].lower()))
    visualize_data['audio_length'].append(len(AudioSegment.from_file(snippet['full_path']))/1000)
for column in visualize_data:
    snippet_df[column] = visualize_data[column]

# Preliminary counts
print("=== Preliminary Total Analysis ===")
print("Mean audio length in seconds:", snippet_df['audio_length'].mean())
print("Mean utterance length in words:", snippet_df['utterance_length'].mean())
print("Total length of audio in hours:", snippet_df['audio_length'].sum()/60/60)
print("Total segments:", len(snippet_df))
print()
print("=== Preliminary By-language Analysis ===")
for group_name, group_df in snippet_df.groupby(['language']):
    print(group_name[0], "segments:")
    print(" Mean audio length in seconds:", group_df['audio_length'].mean())
    print(" Mean utterance length in words:", group_df['utterance_length'].mean())
    print(" Total length of audio in hours:", group_df['audio_length'].sum()/60/60)
    print(" Total segments:", len(group_df))

    if group_name[0] == 'Unknown':
        print(" Unknown utterances:", group_df['text'].to_list()) # These are all numbers. We can basically fix this by filtering out for utterances without numbers later.
        drop = group_df['full_path'].to_list()
print()

# Cleaning the corpus
print("=== Cleaning the corpus ===")
print("There are", len(snippet_df.groupby(['text'])), "unique utterances out of", len(snippet_df), "total utterances")
to_visualize = []
for utterance, group_df in snippet_df.groupby(['text']):
    utterance = utterance[0]
    if len(group_df) > 1:
        to_visualize.append({'unique_text': utterance, 'length': len(group_df)})
to_visualize = pd.DataFrame(to_visualize)
to_visualize = to_visualize.sort_values(by='length', ascending=False)
to_visualize.head(20).plot.bar(x='unique_text', y='length')
# Out:
# === Preliminary Total Analysis ===
# Mean audio length in seconds: 2.304884875499539
# Mean utterance length in words: 4.180756225023056
# Total length of audio in hours: 4.165439166666667
# Total segments: 6506
#
# === Preliminary By-language Analysis ===
# English segments:
#  Mean audio length in seconds: 2.179514182980424
#  Mean utterance length in words: 3.9540551338393928
#  Total length of audio in hours: 1.515367777777778
#  Total segments: 2503
# Spanish segments:
#  Mean audio length in seconds: 2.3789134904714144
#  Mean utterance length in words: 4.334002006018054
#  Total length of audio in hours: 2.6353075
#  Total segments: 3988
# Unknown segments:
#  Mean audio length in seconds: 3.543333333333332
#  Mean utterance length in words: 1.2666666666666666
#  Total length of audio in hours: 0.014763888888888884
#  Total segments: 15
# ...

# %% [markdown]
# I'm too lazy to plot all these things. There's definitely more to look at but for the sake of time I'm going to print them. For the utterances I'm going to manually check for any coder notes.

# %%
# # I printed this out and then looked at it in another tab
# print(snippet_df.sort_values(by=['participant_id', 'interval_id'])[['full_path', 'text']].to_string())

# %% [markdown]
# Things to note:
# - Our data is about 4 hours long.
# - When the language is detected as "unknown" it's likely a numerical value, in which case we should either convert it to text or delete them.
# - Casing, spacing, punctuation will have to be normalized -- Whisper does this automatically.

# %%
# Drop utterances with numerical values + utterances that include coder notes NOTE: Suggest that when coders add their coder notes, they add it in a separate tier
drop += ['../input/finetuning_data/snippets/DINA14_v1_0096_-too-much-noise-to-understand-.wav',
        '../input/finetuning_data/snippets/DINA14_v1_0092_-too-much-noise-to-understand-.wav',
        '../input/finetuning_data/snippets/DINA15_v1_0058_Spanish.wav',
        '../input/finetuning_data/snippets/DINA15_v1_0100_Spanish.wav',
        '../input/finetuning_data/snippets/DINA17_v1_0193_Ay--inaudible-.wav',
        '../input/finetuning_data/snippets/DINA2_v1_0076_Tú---mamí---chewing-sounds-.wav',
        '../input/finetuning_data/snippets/DINA2_v1_0071_-chewing-sounds-.wav',
        '../input/finetuning_data/snippets/DINA2_v1_0160_-chewing-sounds-.wav'
        '../input/finetuning_data/snippets/DINA2_v1_0154_Sil.wav',
        '../input/finetuning_data/snippets/DINA2_v1_0164_-chewing-sounds-.wav',
        '../input/finetuning_data/snippets/DINA2_v1_0188_sil-sil.wav',
        '../input/finetuning_data/snippets/DINA20_v1_0003_-To-much-background-noise-to-understang-.wav',
        '../input/finetuning_data/snippets/DINA20_v1_0026_Va-a-comer-una-sopa--sopita---slurping-noise-.wav',
        '../input/finetuning_data/snippets/DINA20_v1_0027_Ehh---slurping-noise-.wav',
        '../input/finetuning_data/snippets/DINA20_v1_0042_-slurping-noise--otro-otro-café---slurping-noise-.wav']

# I'm going to use the above as a "test" to ensure that I have dropped the correct amount of stuff
things_remove = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0', 'sil', 'too much noise to understand', 'inaudible', 'chewing sounds', 'background noise', 'slurping noise', 'spanish']
keep_rows = []
for index, snippet in snippet_df.iterrows():
  keep = True
  for thing in things_remove:
    if thing in snippet['text'].lower():
      keep = False
  keep_rows.append(keep)
snippet_df['keep'] = keep_rows
final_df = snippet_df[snippet_df['keep'] == True]

# Check
for path in drop:
  if path in final_df['full_path'].to_list():
    print(f"{path} still in final_df")

# Sanity check: How much did I remove?
print("=== Original Data ===")
print("Mean audio length in seconds:", snippet_df['audio_length'].mean())
print("Mean utterance length in words:", snippet_df['utterance_length'].mean())
print("Total length of audio in hours:", snippet_df['audio_length'].sum()/60/60)
print("Total segments:", len(snippet_df))
print()
print("=== Cleaned Data ===")
print("Mean audio length in seconds:", final_df['audio_length'].mean())
print("Mean utterance length in words:", final_df['utterance_length'].mean())
print("Total length of audio in hours:", final_df['audio_length'].sum()/60/60)
print("Total segments:", len(final_df))
print()
# Out:
# === Original Data ===
# Mean audio length in seconds: 2.304884875499539
# Mean utterance length in words: 4.180756225023056
# Total length of audio in hours: 4.165439166666667
# Total segments: 6506
#
# === Cleaned Data ===
# Mean audio length in seconds: 2.2933259925558316
# Mean utterance length in words: 4.186104218362283
# Total length of audio in hours: 4.107601666666667
# Total segments: 6448

# %%
final_df.to_csv('../input/finetuning_data/snippets/data.csv', index=False)

# %% [markdown]
# We should be good to go to start preparing for the finetuning. Since we're finetuning I'm going to switch over to my remote apartment computer now.
# - Download `/snippets` directory

# %% [markdown]
# # 3) Finetuning

# %% [markdown]
# I've moved everything to a file `training.py`

# %%
import os
import torch
import gc
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
torch.backends.cuda.matmul.allow_tf32 = True

def clear_gpu_memory():
    gc.collect()
    torch.cuda.empty_cache()
    if torch.cuda.is_available():
        torch.cuda.synchronize()
clear_gpu_memory()

# ============= Set hyperparameters here =============

LANGUAGE = "spanish" # Could try finetuning the Spanish model too
WHISPER = "medium"
MODEL_NAME = f"openai/whisper-{WHISPER}"
OUTPUT_DIR = f"./whisper-{WHISPER}-DINA"
RANDOM_STATE = 42
STEPS = 20000
LR = 5e-5

import pandas as pd
from sklearn.model_selection import train_test_split

# ============= Format the data for HuggingFace =============

# Import and create split
final_df = pd.read_csv('../input/finetuning_data/snippets/data.csv')
train_df, test_df = train_test_split(final_df, test_size=0.3, random_state=RANDOM_STATE)

# Keep only the necessary columns
train_df = train_df[['full_path', 'text']]
test_df = test_df[['full_path', 'text']]

from datasets import Dataset, DatasetDict, Audio

# Create huggingface dataset
train_hf = Dataset.from_pandas(train_df, preserve_index=False)
test_hf  = Dataset.from_pandas(test_df,  preserve_index=False)
dinav1 = DatasetDict({
    "train": train_hf,
    "test": test_hf
})

# ============= Format the data for Whisper =============

# Load Whisper processors
from transformers import WhisperFeatureExtractor, WhisperTokenizer
feature_extractor = WhisperFeatureExtractor.from_pretrained(MODEL_NAME)
tokenizer = WhisperTokenizer.from_pretrained(MODEL_NAME, language=LANGUAGE, task="transcribe")

# Define generator for processing data
# input_features: path -> load audio w/ torchaudio -> resample to 16k -> feature extraction w/ Whisper -> input_features
# labels: sentence -> tokenize w/ Whisper -> labels
from tqdm import tqdm
import numpy as np
import torchaudio
from datasets import Dataset
target_sr = 16000
def row_generator(stage):
    for i in range(len(dinav1[stage])):
        row = dinav1[stage][i]
        wf, sr = torchaudio.load(row['full_path'])
        if sr != target_sr:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=target_sr)
            wf = resampler(wf)
            sr = target_sr
        wf = wf.flatten().numpy()
        features = feature_extractor(wf, sampling_rate=sr).input_features[0]
        features = features.astype("float64")
        labels = tokenizer(row["text"]).input_ids
        yield {
            "input_features": features,
            "labels": labels
        }
train_processed = Dataset.from_generator(lambda: row_generator("train"))
test_processed  = Dataset.from_generator(lambda: row_generator("test"))
dinav1 = DatasetDict({
    "train": train_processed,
    "test":  test_processed
})

# ============= Load model & get ready for training =============

# Load model
from transformers import WhisperProcessor
from transformers import WhisperForConditionalGeneration
import torch
processor = WhisperProcessor.from_pretrained(MODEL_NAME, language=LANGUAGE, task="transcribe")
model = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
print("Device:", str(device))

# Configure
model.generation_config.language = LANGUAGE.lower()
model.generation_config.task = "transcribe"
model.generation_config.forced_decoder_ids = None
from transformers.models.whisper.tokenization_whisper import LANGUAGES, TO_LANGUAGE_CODE
language_code = TO_LANGUAGE_CODE[LANGUAGE.lower()]
token = f"<|{language_code}|>"
token_id = processor.tokenizer.convert_tokens_to_ids(token)
model.generation_config.lang_to_id[token] = token_id

# Define data collator
import torch
from dataclasses import dataclass
from typing import Any, Dict, List, Union
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    decoder_start_token_id: int
    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)
        if (labels[:, 0] == self.decoder_start_token_id).all().cpu().item():
            labels = labels[:, 1:]
        batch["labels"] = labels
        return batch
data_collator = DataCollatorSpeechSeq2SeqWithPadding(
    processor=processor,
    decoder_start_token_id=model.config.decoder_start_token_id,
)

# Define evaluation metric: WER for English/Spanish
import re
import evaluate
from unicodedata import normalize as unicode_normalize

wer_metric = evaluate.load("wer")
cer_metric = evaluate.load("cer")

def normalize_text(text: str) -> str:
    # Lowercase
    text = text.lower()
    # Unicode normalization (handles accented chars in Spanish, etc.)
    text = unicode_normalize("NFKC", text)
    # Remove punctuation (keeps letters, digits, whitespace)
    text = re.sub(r"[^\w\s]", "", text)
    # Remove underscores (included in \w)
    text = text.replace("_", "")
    # Collapse multiple spaces / strip leading-trailing whitespace
    text = re.sub(r"\s+", " ", text).strip()
    return text

def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    pred_str  = tokenizer.batch_decode(pred_ids,  skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    # ── Normalize before scoring ──────────────────────────────────────────
    pred_str  = [normalize_text(s) for s in pred_str]
    label_str = [normalize_text(s) for s in label_str]

    wer = 100 * wer_metric.compute(predictions=pred_str, references=label_str)
    cer = 100 * cer_metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer, "cer": cer}

# Import loRA related stuff
from peft import LoraConfig, get_peft_model
config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    # No layers_to_transform — apply LoRA everywhere,
    # then freeze encoder weights below
)
model = get_peft_model(model, config)

# Freeze entire encoder including its LoRA params
for name, param in model.named_parameters():
    if "encoder" in name:
        param.requires_grad_(False)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f"Trainable: {trainable:,} / {total:,} ({100*trainable/total:.2f}%)")

# Define arguments
from transformers import Seq2SeqTrainingArguments
training_args = Seq2SeqTrainingArguments(
    output_dir=OUTPUT_DIR,  # change to a repo name of your choice
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,  # increase by 2x for every 2x decrease in batch size
    learning_rate=LR,
    warmup_steps=500,
    max_steps=STEPS,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    fp16=False,
    bf16=True,
    eval_strategy="steps",
    per_device_eval_batch_size=4,
    predict_with_generate=True,
    generation_max_length=128,
    save_steps=500,
    eval_steps=500,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
)

# Define trainer
from transformers import Seq2SeqTrainer, EarlyStoppingCallback
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=dinav1["train"],
    eval_dataset=dinav1["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    processing_class=processor.feature_extractor,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)

# ============= Train =============

torch.cuda.empty_cache()
trainer.train()

# ============= Push =============

kwargs = {
    "dataset_tags": "private",
    "dataset": "private",
    "dataset_args": "config: english, split: test",
    "language": "en",
    "model_name": f"Whisper {WHISPER.capitalize()} English & Spanish - Chengyi Li",
    "finetuned_from": MODEL_NAME,
    "tasks": "automatic-speech-recognition",
}
trainer.push_to_hub(**kwargs)
processor.push_to_hub(f"chengyili2005/whisper-{WHISPER}-DINA")
clear_gpu_memory()

# %% [markdown]
# # 4) Visualize

# %% [markdown]
# Plug in the finetuned model to the current WhisperX pipeline to see if anything's improved.

# %%
from google.colab import userdata
audio_file = 'DINA1_PS1_IDS1.wav'
HF_TOKEN = userdata.get('HF_TOKEN')
# !pip install --upgrade pip
# !pip install --upgrade datasets[audio] accelerate evaluate jiwer tensorboard gradio torchcodec
# !pip install transformers==4.52.0 # Versions reported to work: 4.48.0, 4.50.3, 4.52.0
# !pip install -U bitsandbytes

# %%
# Use a pre-converted model from the Hugging Face Hub
from transformers import (
    AutomaticSpeechRecognitionPipeline,
    WhisperForConditionalGeneration,
    WhisperTokenizer,
    WhisperProcessor,
)
from peft import PeftModel, PeftConfig
import torch


peft_model_id = "chengyili2005/whisper-medium-english-spanish-lora"
language = "en"
task = "transcribe"
peft_config = PeftConfig.from_pretrained(peft_model_id)
model = WhisperForConditionalGeneration.from_pretrained(
    peft_config.base_model_name_or_path, device_map="auto"
)

model = PeftModel.from_pretrained(model, peft_model_id)
tokenizer = WhisperTokenizer.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
processor = WhisperProcessor.from_pretrained(peft_config.base_model_name_or_path, language=language, task=task)
feature_extractor = processor.feature_extractor
forced_decoder_ids = processor.get_decoder_prompt_ids(language=language, task=task)
pipe = AutomaticSpeechRecognitionPipeline(model=model, tokenizer=tokenizer, feature_extractor=feature_extractor)


def transcribe(audio):
    with torch.cuda.amp.autocast():
        text = pipe(audio, generate_kwargs={"forced_decoder_ids": forced_decoder_ids}, batch_size=32, return_timestamps=True) # I also tried chunk_size parameter but it made my whisper model hallucinate a lot
    return text

results = transcribe("DINA1_PS1_IDS1.wav")
# Out:
# Device set to use cuda:0
# /tmp/ipykernel_14706/1597510403.py:29: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.12/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.

# %%
results['chunks']
# Out:
# [{'timestamp': (0.0, 15.56),
#   'text': 'Ok  so grab it to myself  Oh my gosh  I feel like a vlogger  And then just keep it to the side  It should be fine  Ok  cool '},
#  {'timestamp': (15.56, 0.0), 'text': ''},
#  {'timestamp': (22.0, 0.0),
#   'text': "OK  so I'll go ahead and start a 20 minute timer after that and I'll just pump up again  OK  we'll start some questionnaires  OK cool  got it "},
#  {'timestamp': (27.4, 0.0),
#   'text': 'en mami  Qué es eso  Vamos a poner aquí adentro otra vez  Adentro le vamos a poner estos  este y este  Oh  oh  qué vas a hacer  lo vamos a sacar  Ah  gracias uvas  Qué es eso  Ah  gracias '},
#  {'timestamp': (0.0, 26.0),
# ...

# %% [markdown]
# The finetuning is creating a lot of hallucinations. I think I can attribute it to a few weaknesses in our dataset:
# - Not a lot (approximately 3 hours of training data) -> Overfitting
# - Not generalizable (only our proprietary DINA data, which isn't ideal for reporting to a paper as opposed to a more sophisticated dataset)
# - No hyperparameter tuning at inference time

# %% [markdown]
# # Extra

# %% [markdown]
# Now I'm trying a data augmentation approach to getting more accurate transcriptions

# %% [markdown]
# Dataset:
# - Monolingual datasets
# - Synthetic Code Switching Dataset
# - Augmentations
#
# Monolingual datasets:
# - Common Voice English
# - Common Voice Spanish
#
# Real Code Switching Dataset:
# - Bangor Miami Spanish
#
# Synthetic Code Switching Dataset:
# - Use few-shot prompting to ask an LLM to produce parental transcripts that include code-switching
#   - Ensure intersentential code-switching
#   - Ensure code-switching is naturalistic
# - With the text transcript, an ElevenLabs voice model reads them outloud
#
# Augmentations:
# - For all clips, each clip will randomly be sped up / slowed down by a multiplier
#   - 10% faster for 30% of the time
#   - 10% slower for 20% of the time
#   - Regular speed for 50% of the time
# - Add toy/household sounds + infant vocalizations
#
#
#
# General ideas
# - Validate on each dataset
# - Validate on our current DINA transcripts
# - Common Voice ES / EN should compromise 5%, the other 50% compromised of these augmentations.

# %% [markdown]
# Downloading the datasets

# %%
# Bangor Miami Spanish-English Corpus 1.12GB | 35 hours validated
# Common Voice Scripted Speech 24.0 - English 87GB | 2750.41 hours validated
# Common Voice Scripted Speech 24.0 - Spanish 48GB | 591.76 hours validated

# For the Bangor Miami dataset I'll probably leave as is.
# For the large datasets, I'm going to filter only validated samples, defined ages, and balance 50/50 gender in hopes of cutting it down to a smaller size dataset.

# NOTE: I only have around 150 GB of storage left

# %%
from dotenv import load_dotenv
import os

load_dotenv()
MF_KEY = os.getenv("MF_KEY")

# %%
import requests
import os
import time

MF_KEY = os.environ.get("MF_KEY")
filenames = {
    "Common Voice Scripted Speech 24.0 - English.tar.gz" : 'https://datacollective.mozillafoundation.org/api/datasets/cmj8u3p1w0075nxxbe8bedl00/download',
    'Common Voice Scripted Speech 24.0 - Spanish.tar.gz': 'https://datacollective.mozillafoundation.org/api/datasets/cmj8u3p26007dnxxbwyo07lb8/download',
    'Bangor Miami Spanish-English Corpus.tar.gz': 'https://datacollective.mozillafoundation.org/api/datasets/cmmfulo4r018bnz07py4q9t09/download'
}

def get_download_url(download_link):
    response = requests.post(
        download_link,
        headers={
            "Authorization": f"Bearer {MF_KEY}",
            "Content-Type": "application/json"
        }
    )
    response.raise_for_status()
    return response.json()["downloadUrl"]

def download_with_resume(url, filename, chunk_size=8192):
    existing_size = os.path.getsize(filename) if os.path.exists(filename) else 0
    headers = {"Range": f"bytes={existing_size}-"} if existing_size > 0 else {}
    if existing_size:
        print(f"Resuming from {existing_size / 1e9:.2f} GB...")

    with requests.get(url, headers=headers, stream=True, timeout=60) as r:
        r.raise_for_status()
        total = existing_size + int(r.headers.get("content-length", 0))
        mode = "ab" if existing_size else "wb"
        with open(filename, mode) as f:
            downloaded = existing_size
            for chunk in r.iter_content(chunk_size=chunk_size):
                if chunk:
                    f.write(chunk)
                    downloaded += len(chunk)
                    print(f"\r{downloaded / 1e9:.2f} / {total / 1e9:.2f} GB", end="")
    print(f"\nDone: {filename}")

def download_with_retry(filename, download_link, max_retries=20, retry_delay=30):
    attempt = 0
    while attempt < max_retries:
        try:
            print(f"Downloading: {filename} (attempt {attempt + 1}/{max_retries})")
            download_url = get_download_url(download_link)  # Fresh URL each attempt
            download_with_resume(download_url, filename)
            return  # Success — move on to next file
        except Exception as e:
            attempt += 1
            if attempt >= max_retries:
                print(f"\nFailed after {max_retries} attempts: {filename}\nError: {e}")
                raise
            print(f"\nError: {e}")
            print(f"Retrying in {retry_delay}s... ({attempt}/{max_retries})")
            time.sleep(retry_delay)

# Main
for filename, download_link in filenames.items():
    download_with_retry(filename, download_link)
# Out:
# Downloading: Common Voice Scripted Speech 24.0 - English.tar.gz (attempt 1/20)
# Resuming from 73.56 GB...
# 83.82 / 94.21 GB
# Error: HTTPSConnectionPool(host='72ae03f85def1ef3381e3d99f8c68750.eu.r2.cloudflarestorage.com', port=443): Read timed out.
# Retrying in 30s... (1/20)
# Downloading: Common Voice Scripted Speech 24.0 - English.tar.gz (attempt 2/20)
# Resuming from 83.82 GB...
# 94.21 / 94.21 GB
# Done: Common Voice Scripted Speech 24.0 - English.tar.gz
# Downloading: Common Voice Scripted Speech 24.0 - Spanish.tar.gz (attempt 1/20)
# 3.64 / 51.53 GB
# Error: HTTPSConnectionPool(host='72ae03f85def1ef3381e3d99f8c68750.eu.r2.cloudflarestorage.com', port=443): Read timed out.
# Retrying in 30s... (1/20)
# Downloading: Common Voice Scripted Speech 24.0 - Spanish.tar.gz (attempt 2/20)
# Resuming from 3.64 GB...
# 16.34 / 51.53 GB
# Error: HTTPSConnectionPool(host='72ae03f85def1ef3381e3d99f8c68750.eu.r2.cloudflarestorage.com', port=443): Read timed out.
# Retrying in 30s... (2/20)
# ...

# %% [markdown]
# Cleaning the datasets

# %%
# Read the paths.csv file, keep track of files I'm going to use and rm the rest.

# For the Bangor Miami dataset I'll probably leave as is.
# For the English and Spanish datasets, I'm going to filter only validated samples, balance 50/50 gender in hopes of cutting it down to a smaller size dataset.

# NOTE: I only have around 150 GB of storage left
# NOTE: I'm also not using the train/test split generated by Common Voice. I'm using a subset of the data (the files I downloaded) and also applied the following data filters.

EN_validated = '../input/finetuning_data/cv-corpus-24.0-2025-12-05/en/validated.tsv'
ES_validated = '../input/finetuning_data/cv-corpus-24.0-2025-12-05/es/validated.tsv'

import pandas as pd
en_df = pd.read_csv(EN_validated, delimiter='\t')
es_df = pd.read_csv(ES_validated, delimiter='\t')
print("Original sizes.")
print("English:", len(en_df)) # 1869341
print("Spanish:", len(es_df)) # 436590
print()
# columns = ['client_id', 'path', 'sentence_id', 'sentence', 'sentence_domain', 'up_votes', 'down_votes', 'age', 'gender', 'accents', 'variant', 'locale', 'segment']

# Find filter out files that I didn't download
from pathlib import Path
en_parent = Path('../input/finetuning_data/cv-corpus-24.0-2025-12-05/en/clips')
es_parent = Path('../input/finetuning_data/cv-corpus-24.0-2025-12-05/es/clips')

# Filter to only rows whose clip file actually exists on disk
en_df = en_df[en_df['path'].apply(lambda p: (en_parent / p).exists())].reset_index(drop=True)
es_df = es_df[es_df['path'].apply(lambda p: (es_parent / p).exists())].reset_index(drop=True)
print("Filtered for downloaded files.")
print("English:", len(en_df)) # 1006225
print("Spanish:", len(es_df)) # 436590
print()

# Sample 50/50 'gender' — balance to the size of the smaller gender group, keeping only 'male'/'female' rows
def balance_gender(df, seed=42):
    gendered = df[df['gender'].isin(['male_masculine', 'female_feminine'])]
    min_count = gendered.groupby('gender').size().min()
    balanced = (
        gendered.groupby('gender', group_keys=False)
                .apply(lambda g: g.sample(min_count, random_state=seed))
    )
    return balanced.reset_index(drop=True)

en_df = balance_gender(en_df)
es_df = balance_gender(es_df)
print("Balanced for gender.")
print("English:", len(en_df)) # 334570
print("Spanish:", len(es_df)) # 235136
print()

# Sample such that English and Spanish df are the same size
def balance_dataframes(en_df, es_df, seed=42):
    min_size = min(len(en_df), len(es_df))
    en_df = en_df.sample(min_size, random_state=seed).reset_index(drop=True)
    es_df = es_df.sample(min_size, random_state=seed).reset_index(drop=True)
    return en_df, es_df

en_df, es_df = balance_dataframes(en_df, es_df)
print("Balanced for same size.")
print("English:", len(en_df)) # 235136
print("Spanish:", len(es_df)) # 235136
print()

# For every file in the clip directories, if it's not in en_df/es_df respectively, remove it from disk
en_keep = set(en_df['path'].values)
for clip_file in en_parent.iterdir():
    if clip_file.name not in en_keep:
        clip_file.unlink()

es_keep = set(es_df['path'].values)
for clip_file in es_parent.iterdir():
    if clip_file.name not in es_keep:
        clip_file.unlink()

print("Cleanup complete.")
print("English:", len(en_df)) # 235136
print("Spanish:", len(es_df)) # 235136
print()

en_df.to_csv('../input/finetuning_data/english_df.csv', index=False)
es_df.to_csv('../input/finetuning_data/spanish_df.csv', index=False)
# Out:
# /tmp/ipykernel_70717/2883812984.py:13: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   en_df = pd.read_csv(EN_validated, delimiter='\t')
# /tmp/ipykernel_70717/2883812984.py:14: DtypeWarning: Columns (4,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   es_df = pd.read_csv(ES_validated, delimiter='\t')
# Original sizes.
# English: 1869341
# Spanish: 436590
#
# Filtered for downloaded files.
# English: 1006225
# Spanish: 436590
# /tmp/ipykernel_70717/2883812984.py:40: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(min_count, random_state=seed))
# ...

# %%
# Here I'm going to stop and finetune Whisper on just these 2 datasets to see if maybe combining English & Spanish signals in the training data may produce parameters that handle code-switching.

import pandas as pd
from pathlib import Path

# Read
en_df = pd.read_csv('../input/finetuning_data/english_df.csv')
es_df = pd.read_csv('../input/finetuning_data/spanish_df.csv')

# Prepend the respective parent directory to each path
en_parent = Path('../input/finetuning_data/cv-corpus-24.0-2025-12-05/en/clips')
es_parent = Path('../input/finetuning_data/cv-corpus-24.0-2025-12-05/es/clips')
en_df['path'] = en_df['path'].apply(lambda p: str(en_parent / p))
es_df['path'] = es_df['path'].apply(lambda p: str(es_parent / p))

# Combine into 1 dataframe and shuffle
combined_df = pd.concat([en_df, es_df], ignore_index=True).sample(frac=1, random_state=42).reset_index(drop=True)

# Export
combined_df.to_csv('../input/finetuning_data/cv_enes_df.csv', index=False)
print(f"Exported {len(combined_df)} rows to cv_enes_df.csv")
# pd.read_csv('../input/finetuning_data/cv_enes_df.csv') # Important columns: ['path', 'sentence']

# Results: ...
# Out:
# /tmp/ipykernel_70717/2068364973.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   es_df = pd.read_csv('../input/finetuning_data/spanish_df.csv')
# Exported 470272 rows to cv_enes_df.csv

# %%
# TODO
# NOTE: Probably can't use one-shot AI to solve this portion... gonna be a computational headache

# The bangor dataset requires some preprocessing as each clip is an interview rather than a sentence
# 1) Iterate through each .cha file
# 2) Extract the text + timestamps
# 3) Cut up the associating audip file by defined text + timestamps
# 4) Make sure text is machine-learnable (i.e. no annotator notes)

# miami_df.to_csv('../input/finetuning_data/miami_df.csv', index=False)

# %% [markdown]
# Creating the synthetic dataset

# %%
# TODO

# I'm going to use a self-hosted LLM
# - GPT-OSS (120k context window)

# Then, I'm going to feed in an example parent transcript from DINA as an example
# - DINA1_V1_Playsession

# Finally, I'm going to prompt it to produce transcripts similar to the examplar parent transcript, ensuring that:
# - The speech is parent-like
# - Some examples include English-Spanish within-sentence code-switching
# - Utterances in both languages exhibit IDS textual features
# - Utterances are naturalistic

# With these transcripts, I'm going to feed them into ElevenLabs
# - Exploration needed... do they have a "mom" voice model? is there such thing as voice prompting? Jenna might be a good person to ask

# %% [markdown]
# Apply data augmentations

# %%
# TODO

# %% [markdown]
# Train again

# %%
# TODO: training.py
